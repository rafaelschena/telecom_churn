# %% [markdown]
# # Prevendo a rotatividade de clientes de uma empresa de Telecom
# ### Projeto nº4 da Formação Cientista de Dados da Data Science Academy
# O objetivo é trabalho é criar um modelo de aprendizagem de máquina que possa prever se um cliente pode ou não cancelar seu plano e qual a probabilidade de isso ocorrer.
#
# Para isto, são fornecidos um dataset de treinamento, para treinamento e *cross-validation* dos modelos, e também um dataset de teste para mensuração final do resultado do modelo.
#
# Será utilizada a a métrica do R^2 para avaliação dos modelos de machine learning criados.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Análise Exploratória de Dados

# %%
df = pd.read_csv('data/projeto4_telecom_treino.csv')
df
# Out:
#       Unnamed: 0 state  account_length      area_code international_plan  \
# 0              1    KS             128  area_code_415                 no
# 1              2    OH             107  area_code_415                 no
# 2              3    NJ             137  area_code_415                 no
# 3              4    OH              84  area_code_408                yes
# 4              5    OK              75  area_code_415                yes
# ...          ...   ...             ...            ...                ...
# 3328        3329    AZ             192  area_code_415                 no
# 3329        3330    WV              68  area_code_415                 no
# 3330        3331    RI              28  area_code_510                 no
# 3331        3332    CT             184  area_code_510                yes
# 3332        3333    TN              74  area_code_415                 no
#
#      voice_mail_plan  number_vmail_messages  total_day_minutes  \
# 0                yes                     25              265.1
# 1                yes                     26              161.6
# 2                 no                      0              243.4
# 3                 no                      0              299.4
# 4                 no                      0              166.7
# ...              ...                    ...                ...
# 3328             yes                     36              156.2
# 3329              no                      0              231.1
# 3330              no                      0              180.8
# 3331              no                      0              213.8
# 3332             yes                     25              234.4
#
#       total_day_calls  total_day_charge  ...  total_eve_calls  \
# 0                 110             45.07  ...               99
# 1                 123             27.47  ...              103
# 2                 114             41.38  ...              110
# 3                  71             50.90  ...               88
# 4                 113             28.34  ...              122
# ...               ...               ...  ...              ...
# 3328               77             26.55  ...              126
# 3329               57             39.29  ...               55
# 3330              109             30.74  ...               58
# 3331              105             36.35  ...               84
# 3332              113             39.85  ...               82
#
#       total_eve_charge  total_night_minutes  total_night_calls  \
# 0                16.78                244.7                 91
# 1                16.62                254.4                103
# 2                10.30                162.6                104
# 3                 5.26                196.9                 89
# 4                12.61                186.9                121
# ...                ...                  ...                ...
# 3328             18.32                279.1                 83
# 3329             13.04                191.3                123
# 3330             24.55                191.9                 91
# 3331             13.57                139.2                137
# 3332             22.60                241.4                 77
#
#       total_night_charge  total_intl_minutes  total_intl_calls  \
# 0                  11.01                10.0                 3
# 1                  11.45                13.7                 3
# 2                   7.32                12.2                 5
# 3                   8.86                 6.6                 7
# 4                   8.41                10.1                 3
# ...                  ...                 ...               ...
# 3328               12.56                 9.9                 6
# 3329                8.61                 9.6                 4
# 3330                8.64                14.1                 6
# 3331                6.26                 5.0                10
# 3332               10.86                13.7                 4
#
#       total_intl_charge  number_customer_service_calls  churn
# 0                  2.70                              1     no
# 1                  3.70                              1     no
# 2                  3.29                              0     no
# 3                  1.78                              2     no
# 4                  2.73                              3     no
# ...                 ...                            ...    ...
# 3328               2.67                              2     no
# 3329               2.59                              3     no
# 3330               3.81                              2     no
# 3331               1.35                              2     no
# 3332               3.70                              0     no
#
# [3333 rows x 21 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0  account_length  number_vmail_messages  total_day_minutes  \
# count  3333.00000     3333.000000            3333.000000        3333.000000
# mean   1667.00000      101.064806               8.099010         179.775098
# std     962.29855       39.822106              13.688365          54.467389
# min       1.00000        1.000000               0.000000           0.000000
# 25%     834.00000       74.000000               0.000000         143.700000
# 50%    1667.00000      101.000000               0.000000         179.400000
# 75%    2500.00000      127.000000              20.000000         216.400000
# max    3333.00000      243.000000              51.000000         350.800000
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# std          20.069084          9.259435          50.713844        19.922625
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.430000         166.600000        87.000000
# 50%         101.000000         30.500000         201.400000       100.000000
# 75%         114.000000         36.790000         235.300000       114.000000
# max         165.000000         59.640000         363.700000       170.000000
#
#        total_eve_charge  total_night_minutes  total_night_calls  \
# count       3333.000000          3333.000000        3333.000000
# mean          17.083540           200.872037         100.107711
# std            4.310668            50.573847          19.568609
# min            0.000000            23.200000          33.000000
# 25%           14.160000           167.000000          87.000000
# 50%           17.120000           201.200000         100.000000
# 75%           20.000000           235.300000         113.000000
# max           30.910000           395.000000         175.000000
#
#        total_night_charge  total_intl_minutes  total_intl_calls  \
# count         3333.000000         3333.000000       3333.000000
# mean             9.039325           10.237294          4.479448
# std              2.275873            2.791840          2.461214
# min              1.040000            0.000000          0.000000
# 25%              7.520000            8.500000          3.000000
# 50%              9.050000           10.300000          4.000000
# 75%             10.590000           12.100000          6.000000
# max             17.770000           20.000000         20.000000
#
#        total_intl_charge  number_customer_service_calls
# count        3333.000000                    3333.000000
# mean            2.764581                       1.562856
# std             0.753773                       1.315491
# min             0.000000                       0.000000
# 25%             2.300000                       1.000000
# 50%             2.780000                       1.000000
# 75%             3.270000                       2.000000
# max             5.400000                       9.000000

# %%
df.dropna()
# Out:
#       Unnamed: 0 state  account_length      area_code international_plan  \
# 0              1    KS             128  area_code_415                 no
# 1              2    OH             107  area_code_415                 no
# 2              3    NJ             137  area_code_415                 no
# 3              4    OH              84  area_code_408                yes
# 4              5    OK              75  area_code_415                yes
# ...          ...   ...             ...            ...                ...
# 3328        3329    AZ             192  area_code_415                 no
# 3329        3330    WV              68  area_code_415                 no
# 3330        3331    RI              28  area_code_510                 no
# 3331        3332    CT             184  area_code_510                yes
# 3332        3333    TN              74  area_code_415                 no
#
#      voice_mail_plan  number_vmail_messages  total_day_minutes  \
# 0                yes                     25              265.1
# 1                yes                     26              161.6
# 2                 no                      0              243.4
# 3                 no                      0              299.4
# 4                 no                      0              166.7
# ...              ...                    ...                ...
# 3328             yes                     36              156.2
# 3329              no                      0              231.1
# 3330              no                      0              180.8
# 3331              no                      0              213.8
# 3332             yes                     25              234.4
#
#       total_day_calls  total_day_charge  ...  total_eve_calls  \
# 0                 110             45.07  ...               99
# 1                 123             27.47  ...              103
# 2                 114             41.38  ...              110
# 3                  71             50.90  ...               88
# 4                 113             28.34  ...              122
# ...               ...               ...  ...              ...
# 3328               77             26.55  ...              126
# 3329               57             39.29  ...               55
# 3330              109             30.74  ...               58
# 3331              105             36.35  ...               84
# 3332              113             39.85  ...               82
#
#       total_eve_charge  total_night_minutes  total_night_calls  \
# 0                16.78                244.7                 91
# 1                16.62                254.4                103
# 2                10.30                162.6                104
# 3                 5.26                196.9                 89
# 4                12.61                186.9                121
# ...                ...                  ...                ...
# 3328             18.32                279.1                 83
# 3329             13.04                191.3                123
# 3330             24.55                191.9                 91
# 3331             13.57                139.2                137
# 3332             22.60                241.4                 77
#
#       total_night_charge  total_intl_minutes  total_intl_calls  \
# 0                  11.01                10.0                 3
# 1                  11.45                13.7                 3
# 2                   7.32                12.2                 5
# 3                   8.86                 6.6                 7
# 4                   8.41                10.1                 3
# ...                  ...                 ...               ...
# 3328               12.56                 9.9                 6
# 3329                8.61                 9.6                 4
# 3330                8.64                14.1                 6
# 3331                6.26                 5.0                10
# 3332               10.86                13.7                 4
#
#       total_intl_charge  number_customer_service_calls  churn
# 0                  2.70                              1     no
# 1                  3.70                              1     no
# 2                  3.29                              0     no
# 3                  1.78                              2     no
# 4                  2.73                              3     no
# ...                 ...                            ...    ...
# 3328               2.67                              2     no
# 3329               2.59                              3     no
# 3330               3.81                              2     no
# 3331               1.35                              2     no
# 3332               3.70                              0     no
#
# [3333 rows x 21 columns]

# %% [markdown]
# Como o comando dropna não altera o número de linhas do dataset, pode-se concluir que não há dados faltantes no conjunto de dados.

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# state                             object
# account_length                     int64
# area_code                         object
# international_plan                object
# voice_mail_plan                   object
# number_vmail_messages              int64
# total_day_minutes                float64
# total_day_calls                    int64
# total_day_charge                 float64
# total_eve_minutes                float64
# total_eve_calls                    int64
# total_eve_charge                 float64
# total_night_minutes              float64
# total_night_calls                  int64
# total_night_charge               float64
# total_intl_minutes               float64
# total_intl_calls                   int64
# total_intl_charge                float64
# number_customer_service_calls      int64
# churn                             object
# dtype: object

# %%
df.dtypes[df.dtypes.values=='object']
# Out:
# state                 object
# area_code             object
# international_plan    object
# voice_mail_plan       object
# churn                 object
# dtype: object

# %%
df.dtypes[df.dtypes.values!='object']
# Out:
# Unnamed: 0                         int64
# account_length                     int64
# number_vmail_messages              int64
# total_day_minutes                float64
# total_day_calls                    int64
# total_day_charge                 float64
# total_eve_minutes                float64
# total_eve_calls                    int64
# total_eve_charge                 float64
# total_night_minutes              float64
# total_night_calls                  int64
# total_night_charge               float64
# total_intl_minutes               float64
# total_intl_calls                   int64
# total_intl_charge                float64
# number_customer_service_calls      int64
# dtype: object

# %% [markdown]
# O *dataset* é constituído por 15 variáveis numéricas e 5 variáveis categóricas. Uma das variáveis é o índice, que deve ser desconsiderado na análise por não acrescentar informação sobre o cliente.

# %%
df.set_index('Unnamed: 0', inplace=True)
df
# Out:
#            state  account_length      area_code international_plan  \
# Unnamed: 0
# 1             KS             128  area_code_415                 no
# 2             OH             107  area_code_415                 no
# 3             NJ             137  area_code_415                 no
# 4             OH              84  area_code_408                yes
# 5             OK              75  area_code_415                yes
# ...          ...             ...            ...                ...
# 3329          AZ             192  area_code_415                 no
# 3330          WV              68  area_code_415                 no
# 3331          RI              28  area_code_510                 no
# 3332          CT             184  area_code_510                yes
# 3333          TN              74  area_code_415                 no
#
#            voice_mail_plan  number_vmail_messages  total_day_minutes  \
# Unnamed: 0
# 1                      yes                     25              265.1
# 2                      yes                     26              161.6
# 3                       no                      0              243.4
# 4                       no                      0              299.4
# 5                       no                      0              166.7
# ...                    ...                    ...                ...
# 3329                   yes                     36              156.2
# 3330                    no                      0              231.1
# 3331                    no                      0              180.8
# 3332                    no                      0              213.8
# 3333                   yes                     25              234.4
#
#             total_day_calls  total_day_charge  total_eve_minutes  \
# Unnamed: 0
# 1                       110             45.07              197.4
# 2                       123             27.47              195.5
# 3                       114             41.38              121.2
# 4                        71             50.90               61.9
# 5                       113             28.34              148.3
# ...                     ...               ...                ...
# 3329                     77             26.55              215.5
# 3330                     57             39.29              153.4
# 3331                    109             30.74              288.8
# 3332                    105             36.35              159.6
# 3333                    113             39.85              265.9
#
#             total_eve_calls  total_eve_charge  total_night_minutes  \
# Unnamed: 0
# 1                        99             16.78                244.7
# 2                       103             16.62                254.4
# 3                       110             10.30                162.6
# 4                        88              5.26                196.9
# 5                       122             12.61                186.9
# ...                     ...               ...                  ...
# 3329                    126             18.32                279.1
# 3330                     55             13.04                191.3
# 3331                     58             24.55                191.9
# 3332                     84             13.57                139.2
# 3333                     82             22.60                241.4
#
#             total_night_calls  total_night_charge  total_intl_minutes  \
# Unnamed: 0
# 1                          91               11.01                10.0
# 2                         103               11.45                13.7
# 3                         104                7.32                12.2
# 4                          89                8.86                 6.6
# 5                         121                8.41                10.1
# ...                       ...                 ...                 ...
# 3329                       83               12.56                 9.9
# 3330                      123                8.61                 9.6
# 3331                       91                8.64                14.1
# 3332                      137                6.26                 5.0
# 3333                       77               10.86                13.7
#
#             total_intl_calls  total_intl_charge  \
# Unnamed: 0
# 1                          3               2.70
# 2                          3               3.70
# 3                          5               3.29
# 4                          7               1.78
# 5                          3               2.73
# ...                      ...                ...
# 3329                       6               2.67
# 3330                       4               2.59
# 3331                       6               3.81
# 3332                      10               1.35
# 3333                       4               3.70
#
#             number_customer_service_calls churn
# Unnamed: 0
# 1                                       1    no
# 2                                       1    no
# 3                                       0    no
# 4                                       2    no
# 5                                       3    no
# ...                                   ...   ...
# 3329                                    2    no
# 3330                                    3    no
# 3331                                    2    no
# 3332                                    2    no
# 3333                                    0    no
#
# [3333 rows x 20 columns]

# %%
numericas = df[df.dtypes[df.dtypes.values!='object'].index]
numericas
# Out:
#             account_length  number_vmail_messages  total_day_minutes  \
# Unnamed: 0
# 1                      128                     25              265.1
# 2                      107                     26              161.6
# 3                      137                      0              243.4
# 4                       84                      0              299.4
# 5                       75                      0              166.7
# ...                    ...                    ...                ...
# 3329                   192                     36              156.2
# 3330                    68                      0              231.1
# 3331                    28                      0              180.8
# 3332                   184                      0              213.8
# 3333                    74                     25              234.4
#
#             total_day_calls  total_day_charge  total_eve_minutes  \
# Unnamed: 0
# 1                       110             45.07              197.4
# 2                       123             27.47              195.5
# 3                       114             41.38              121.2
# 4                        71             50.90               61.9
# 5                       113             28.34              148.3
# ...                     ...               ...                ...
# 3329                     77             26.55              215.5
# 3330                     57             39.29              153.4
# 3331                    109             30.74              288.8
# 3332                    105             36.35              159.6
# 3333                    113             39.85              265.9
#
#             total_eve_calls  total_eve_charge  total_night_minutes  \
# Unnamed: 0
# 1                        99             16.78                244.7
# 2                       103             16.62                254.4
# 3                       110             10.30                162.6
# 4                        88              5.26                196.9
# 5                       122             12.61                186.9
# ...                     ...               ...                  ...
# 3329                    126             18.32                279.1
# 3330                     55             13.04                191.3
# 3331                     58             24.55                191.9
# 3332                     84             13.57                139.2
# 3333                     82             22.60                241.4
#
#             total_night_calls  total_night_charge  total_intl_minutes  \
# Unnamed: 0
# 1                          91               11.01                10.0
# 2                         103               11.45                13.7
# 3                         104                7.32                12.2
# 4                          89                8.86                 6.6
# 5                         121                8.41                10.1
# ...                       ...                 ...                 ...
# 3329                       83               12.56                 9.9
# 3330                      123                8.61                 9.6
# 3331                       91                8.64                14.1
# 3332                      137                6.26                 5.0
# 3333                       77               10.86                13.7
#
#             total_intl_calls  total_intl_charge  number_customer_service_calls
# Unnamed: 0
# 1                          3               2.70                              1
# 2                          3               3.70                              1
# 3                          5               3.29                              0
# 4                          7               1.78                              2
# 5                          3               2.73                              3
# ...                      ...                ...                            ...
# 3329                       6               2.67                              2
# 3330                       4               2.59                              3
# 3331                       6               3.81                              2
# 3332                      10               1.35                              2
# 3333                       4               3.70                              0
#
# [3333 rows x 15 columns]

# %%
categoricas = df[df.dtypes[df.dtypes.values=='object'].index]
categoricas
# Out:
#            state      area_code international_plan voice_mail_plan churn
# Unnamed: 0
# 1             KS  area_code_415                 no             yes    no
# 2             OH  area_code_415                 no             yes    no
# 3             NJ  area_code_415                 no              no    no
# 4             OH  area_code_408                yes              no    no
# 5             OK  area_code_415                yes              no    no
# ...          ...            ...                ...             ...   ...
# 3329          AZ  area_code_415                 no             yes    no
# 3330          WV  area_code_415                 no              no    no
# 3331          RI  area_code_510                 no              no    no
# 3332          CT  area_code_510                yes              no    no
# 3333          TN  area_code_415                 no             yes    no
#
# [3333 rows x 5 columns]

# %%
# Verificando quantos valores únicos há em cada coluna do dataset de variáveis categóricas
n_unicos = pd.DataFrame(columns=['N_unicos'])
for col in categoricas.columns:
    n_unicos.loc[col] = len(df[col].unique())

# %%
n_unicos
# Out:
#                    N_unicos
# state                    51
# area_code                 3
# international_plan        2
# voice_mail_plan           2
# churn                     2

# %% [markdown]
# Verificando agora a distribuição destas variáveis categóricas entre os *labels* 0 e 1 do *churn*. A intenção é constatar graficamente se as mesmas são significativas para a rotatividade de clientes.

# %%
n_unicos.index
# Out:
# Index(['state', 'area_code', 'international_plan', 'voice_mail_plan', 'churn'], dtype='object')

# %%
tabela = df[['area_code', 'churn', 'account_length']]
tabela
# Out:
#                 area_code churn  account_length
# Unnamed: 0
# 1           area_code_415    no             128
# 2           area_code_415    no             107
# 3           area_code_415    no             137
# 4           area_code_408    no              84
# 5           area_code_415    no              75
# ...                   ...   ...             ...
# 3329        area_code_415    no             192
# 3330        area_code_415    no              68
# 3331        area_code_510    no              28
# 3332        area_code_510    no             184
# 3333        area_code_415    no              74
#
# [3333 rows x 3 columns]

# %%
agregado = tabela.pivot_table(index='area_code', columns='churn', values='account_length', aggfunc='count')
agregado
# Out:
# churn            no  yes
# area_code
# area_code_408   716  122
# area_code_415  1419  236
# area_code_510   715  125

# %%
df['state']
# Out:
# Unnamed: 0
# 1       KS
# 2       OH
# 3       NJ
# 4       OH
# 5       OK
#         ..
# 3329    AZ
# 3330    WV
# 3331    RI
# 3332    CT
# 3333    TN
# Name: state, Length: 3333, dtype: object

# %%
labels = df['state'].unique()
labels
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
x = np.arange(len(labels)) # locais dos labels no gráfico
width = 0.35 # largura das barras

# %%
agregado['total'] = agregado.yes + agregado.no

# %%
agregado['perc_yes'] = agregado.yes/agregado.total
agregado['perc_no'] = agregado.no/agregado.total

# %%
agregado
# Out:
# churn  no  yes  total  perc_yes   perc_no
# state
# AK     49    3     52  0.057692  0.942308
# AL     72    8     80  0.100000  0.900000
# AR     44   11     55  0.200000  0.800000
# AZ     60    4     64  0.062500  0.937500
# CA     25    9     34  0.264706  0.735294
# CO     57    9     66  0.136364  0.863636
# CT     62   12     74  0.162162  0.837838
# DC     49    5     54  0.092593  0.907407
# DE     52    9     61  0.147541  0.852459
# FL     55    8     63  0.126984  0.873016
# GA     46    8     54  0.148148  0.851852
# HI     50    3     53  0.056604  0.943396
# IA     41    3     44  0.068182  0.931818
# ID     64    9     73  0.123288  0.876712
# IL     53    5     58  0.086207  0.913793
# IN     62    9     71  0.126761  0.873239
# KS     57   13     70  0.185714  0.814286
# KY     51    8     59  0.135593  0.864407
# LA     47    4     51  0.078431  0.921569
# MA     54   11     65  0.169231  0.830769
# MD     53   17     70  0.242857  0.757143
# ME     49   13     62  0.209677  0.790323
# MI     57   16     73  0.219178  0.780822
# MN     69   15     84  0.178571  0.821429
# MO     56    7     63  0.111111  0.888889
# MS     51   14     65  0.215385  0.784615
# MT     54   14     68  0.205882  0.794118
# NC     57   11     68  0.161765  0.838235
# ND     56    6     62  0.096774  0.903226
# NE     56    5     61  0.081967  0.918033
# NH     47    9     56  0.160714  0.839286
# NJ     50   18     68  0.264706  0.735294
# NM     56    6     62  0.096774  0.903226
# NV     52   14     66  0.212121  0.787879
# NY     68   15     83  0.180723  0.819277
# OH     68   10     78  0.128205  0.871795
# OK     52    9     61  0.147541  0.852459
# OR     67   11     78  0.141026  0.858974
# PA     37    8     45  0.177778  0.822222
# RI     59    6     65  0.092308  0.907692
# SC     46   14     60  0.233333  0.766667
# SD     52    8     60  0.133333  0.866667
# TN     48    5     53  0.094340  0.905660
# TX     54   18     72  0.250000  0.750000
# UT     62   10     72  0.138889  0.861111
# VA     72    5     77  0.064935  0.935065
# VT     65    8     73  0.109589  0.890411
# WA     52   14     66  0.212121  0.787879
# WI     71    7     78  0.089744  0.910256
# WV     96   10    106  0.094340  0.905660
# WY     68    9     77  0.116883  0.883117

# %%
fig, ax = plt.subplots(figsize=(20, 10))
#rects1 = ax.bar(x - width/2, agregado['perc_no'], width, label='No')
rects2 = ax.bar(x + width/2, agregado['perc_yes'], width, label='Yes')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Observações')
ax.set_title('Observações de churn por estado')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# %%
for var in n_unicos.index[:-1]:
    tabela = df[[var, 'churn', 'account_length']].set_index(var)
    agregado = tabela.pivot_table(index=var, columns='churn', values='account_length', aggfunc='count')
    agregado['total'] = agregado.yes + agregado.no
    agregado['perc_yes'] = agregado.yes/agregado.total
    agregado['perc_no'] = agregado.no/agregado.total
    
    fig, ax = plt.subplots(figsize=(20, 10))
    #rects1 = ax.bar(x - width/2, agregado['perc_no'], width, label='No')
    rects2 = ax.bar(x + width/2, agregado['perc_yes'], width, label='Yes')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Observações %')
    ax.set_title(f'% de churn por {var}')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-c4873a2f4c3e> in <module>
#       8     fig, ax = plt.subplots(figsize=(20, 10))
#       9     #rects1 = ax.bar(x - width/2, agregado['perc_no'], width, label='No')
# ---> 10     rects2 = ax.bar(x + width/2, agregado['perc_yes'], width, label='Yes')
#      11
#      12     # Add some text for labels, title and custom x-axis tick labels, etc.
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2373         x, height, width, y, linewidth = np.broadcast_arrays(
#    2374             # Make args iterable too.
# -> 2375             np.atleast_1d(x), height, width, y, linewidth)
#    2376
#    2377         # Now that units have been converted, set the tick locations.
#
# ~\Anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     257     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     258
# --> 259     shape = _broadcast_shape(*args)
#     260
#     261     if all(array.shape == shape for array in args):
#
# ~\Anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     191     # use the old-iterator because np.nditer does not handle size 0 arrays
#     192     # consistently
# --> 193     b = np.broadcast(*args[:32])
#     194     # unfortunately, it cannot handle 32 or more arguments directly
#     195     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %% [markdown]
# Próximos passos:
# - Imprimir gráficos de churn por categorias das variáveis discretas
# - Imprimir gráficos de boxplot das variáveis contínuas pelas categorias de churn
